# %%
#data manipuöation
import pandas as pd

#data visualisation
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df= pd.read_csv(r'C:\Users\USER\Downloads\supermarket_sales_datasets.csv')
df
# Out:
#       Invoice_ID Branch       City Customer_type  Gender         Product_line  \
# 0    101-17-6199      A     Yangon        Normal    Male   Food and beverages
# 1    101-81-4070      C  Naypyitaw        Member  Female    Health and beauty
# 2    102-06-2002      C  Naypyitaw        Member    Male    Sports and travel
# 3    102-77-2261      C  Naypyitaw        Member    Male    Health and beauty
# 4    105-10-6182      A     Yangon        Member    Male  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 995  894-41-5205      C  Naypyitaw        Normal  Female   Food and beverages
# 996  895-03-6665      B   Mandalay        Normal  Female  Fashion accessories
# 997  895-66-0685      B   Mandalay        Member    Male   Food and beverages
# 998  896-34-0956      A     Yangon        Normal    Male  Fashion accessories
# 999  898-04-2717      A     Yangon        Normal    Male  Fashion accessories
#
# ...

# %% [markdown]
# # data audit

# %%
# First five rows
df.head()
# Out:
#     Invoice_ID Branch       City Customer_type  Gender         Product_line  \
# 0  101-17-6199      A     Yangon        Normal    Male   Food and beverages
# 1  101-81-4070      C  Naypyitaw        Member  Female    Health and beauty
# 2  102-06-2002      C  Naypyitaw        Member    Male    Sports and travel
# 3  102-77-2261      C  Naypyitaw        Member    Male    Health and beauty
# 4  105-10-6182      A     Yangon        Member    Male  Fashion accessories
#
#    Unit_price  Quantity   Tax_5%     Total              Date   Time  \
# 0       45.79         7  16.0265  336.5565     13 March 2019  19:44
# 1       62.82         2   6.2820  131.9220   17 January 2019  12:36
# 2       25.25         5   6.3125  132.5625     20 March 2019  17:52
# 3       65.31         7  22.8585  480.0285       03 May 2019  18:02
# 4       21.48         2   2.1480   45.1080  27 February 2019  12:22
#
#        Payment    cogs  gross_margin_percentage  gross_income  Rating
# ...

# %%
# Last five rows
df.tail()
# Out:
#       Invoice_ID Branch       City Customer_type  Gender         Product_line  \
# 995  894-41-5205      C  Naypyitaw        Normal  Female   Food and beverages
# 996  895-03-6665      B   Mandalay        Normal  Female  Fashion accessories
# 997  895-66-0685      B   Mandalay        Member    Male   Food and beverages
# 998  896-34-0956      A     Yangon        Normal    Male  Fashion accessories
# 999  898-04-2717      A     Yangon        Normal    Male  Fashion accessories
#
#      Unit_price  Quantity   Tax_5%     Total              Date   Time  \
# 995       43.18         8  17.2720  362.7120   19 January 2019  19:39
# 996       36.51         9  16.4295  345.0195  16 February 2019  10:52
# 997       18.08         3   2.7120   56.9520       03 May 2019  19:46
# 998       21.32         1   1.0660   22.3860   26 January 2019  12:43
# 999       76.40         9  34.3800  721.9800     19 March 2019  15:49
#
#          Payment    cogs  gross_margin_percentage  gross_income  Rating
# ...

# %%
#shape at the dataframe
df.shape
# Out:
# (1000, 17)

# %%
#columns present in the datasets
df.columns
# Out:
# Index(['Invoice_ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax_5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross_margin_percentage', 'gross_income',
#        'Rating'],
#       dtype='object')

# %%
# types of the data
df.dtypes
# Out:
# Invoice_ID                  object
# Branch                      object
# City                        object
# Customer_type               object
# Gender                      object
# Product_line                object
# Unit_price                 float64
# Quantity                     int64
# Tax_5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross_margin_percentage    float64
# gross_income               float64
# Rating                     float64
# dtype: object

# %%
#A concise summary of the datasets

df.info
# Out:
# <bound method DataFrame.info of       Invoice_ID Branch       City Customer_type  Gender         Product_line  \
# 0    101-17-6199      A     Yangon        Normal    Male   Food and beverages
# 1    101-81-4070      C  Naypyitaw        Member  Female    Health and beauty
# 2    102-06-2002      C  Naypyitaw        Member    Male    Sports and travel
# 3    102-77-2261      C  Naypyitaw        Member    Male    Health and beauty
# 4    105-10-6182      A     Yangon        Member    Male  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 995  894-41-5205      C  Naypyitaw        Normal  Female   Food and beverages
# 996  895-03-6665      B   Mandalay        Normal  Female  Fashion accessories
# 997  895-66-0685      B   Mandalay        Member    Male   Food and beverages
# 998  896-34-0956      A     Yangon        Normal    Male  Fashion accessories
# 999  898-04-2717      A     Yangon        Normal    Male  Fashion accessories
#
# ...

# %%
#checking missing values
df.isnull().sum()
# Out:
# Invoice_ID                 0
# Branch                     0
# City                       0
# Customer_type              0
# Gender                     0
# Product_line               0
# Unit_price                 0
# Quantity                   0
# Tax_5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross_margin_percentage    0
# gross_income               0
# Rating                     0
# dtype: int64

# %%
#Getting descriptive statistics summary

df.describe()
# Out:
#         Unit_price     Quantity       Tax_5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross_margin_percentage  gross_income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# # Exploratary Data analysis

# %%
#overall sales trends

df['Date'].min()
# Out:
# '01 April 2019'

# %%
df['Date'].max()
# Out:
# '31 January 2019'

# %%
# getting month year from the datasets

df['month_year'] = df['Date'].astype(str).str[3:]
df
# Out:
#       Invoice_ID Branch       City Customer_type  Gender         Product_line  \
# 0    101-17-6199      A     Yangon        Normal    Male   Food and beverages
# 1    101-81-4070      C  Naypyitaw        Member  Female    Health and beauty
# 2    102-06-2002      C  Naypyitaw        Member    Male    Sports and travel
# 3    102-77-2261      C  Naypyitaw        Member    Male    Health and beauty
# 4    105-10-6182      A     Yangon        Member    Male  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 995  894-41-5205      C  Naypyitaw        Normal  Female   Food and beverages
# 996  895-03-6665      B   Mandalay        Normal  Female  Fashion accessories
# 997  895-66-0685      B   Mandalay        Member    Male   Food and beverages
# 998  896-34-0956      A     Yangon        Normal    Male  Fashion accessories
# 999  898-04-2717      A     Yangon        Normal    Male  Fashion accessories
#
# ...

# %%
df['Date'] = pd.to_datetime(df.Date)
df
# Out:
#       Invoice_ID Branch       City Customer_type  Gender         Product_line  \
# 0    101-17-6199      A     Yangon        Normal    Male   Food and beverages
# 1    101-81-4070      C  Naypyitaw        Member  Female    Health and beauty
# 2    102-06-2002      C  Naypyitaw        Member    Male    Sports and travel
# 3    102-77-2261      C  Naypyitaw        Member    Male    Health and beauty
# 4    105-10-6182      A     Yangon        Member    Male  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 995  894-41-5205      C  Naypyitaw        Normal  Female   Food and beverages
# 996  895-03-6665      B   Mandalay        Normal  Female  Fashion accessories
# 997  895-66-0685      B   Mandalay        Member    Male   Food and beverages
# 998  896-34-0956      A     Yangon        Normal    Male  Fashion accessories
# 999  898-04-2717      A     Yangon        Normal    Male  Fashion accessories
#
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2019-12-03 00:00:00')

# %%
df.groupby('month_year').sum()
# Out:
#                 Unit_price  Quantity     Tax_5%       Total      cogs  \
# month_year
# April 2019         1448.32       157   378.9345   7957.6245   7578.69
# August 2019        2112.00       225   643.0370  13503.7770  12860.74
# December 2019      1770.22       183   564.8240  11861.3040  11296.48
# February 2019     11614.59      1072  3008.0830  63169.7430  60161.66
# January 2019      14793.81      1445  4122.0270  86562.5670  82440.54
# July 2019          1965.78       218   547.6530  11500.7130  10953.06
# June 2019          1709.12       188   457.7250   9612.2250   9154.50
# March 2019        12559.24      1254  3464.2500  72749.2500  69285.00
# May 2019           2371.13       212   609.4615  12798.6915  12189.23
# November 2019      1661.39       154   458.0175   9618.3675   9160.35
# October 2019       1651.13       176   469.7715   9865.2015   9395.43
# September 2019     2015.40       226   655.5850  13767.2850  13111.70
#
# ...

# %%
df_monthly_sale =df.groupby('month_year').sum()['Total'].reset_index()
df_monthly_sale
# Out:
#         month_year       Total
# 0       April 2019   7957.6245
# 1      August 2019  13503.7770
# 2    December 2019  11861.3040
# 3    February 2019  63169.7430
# 4     January 2019  86562.5670
# 5        July 2019  11500.7130
# 6        June 2019   9612.2250
# 7       March 2019  72749.2500
# 8         May 2019  12798.6915
# 9    November 2019   9618.3675
# 10    October 2019   9865.2015
# 11  September 2019  13767.2850

# %%
plt.figure(figsize=(15,6)) 
plt.plot(df_monthly_sale['month_year'],df_monthly_sale['Total'], color='red')
plt.xticks(rotation = 'vertical', size=8)
plt.show()

# %%
df['Date'] = pd.to_datetime(df.Date)
df_num_date = df['month_year'] = df['Date'].astype(str).str[5:]
df_num_date
# Out:
# 0      03-13
# 1      01-17
# 2      03-20
# 3      05-03
# 4      02-27
#        ...
# 995    01-19
# 996    02-16
# 997    05-03
# 998    01-26
# 999    03-19
# Name: Date, Length: 1000, dtype: object

# %%
df_daily_sale =df.groupby('month_year').sum()['Total'].reset_index()
df_daily_sale
# Out:
#    month_year      Total
# 0       01-01  4745.1810
# 1       01-02  2444.5365
# 2       01-03  2634.3660
# 3       01-13  2451.2040
# 4       01-14  3966.6165
# ..        ...        ...
# 84      11-02  4542.1530
# 85      11-03  2961.2520
# 86      12-01  5184.7635
# 87      12-02  2998.9890
# 88      12-03  3677.5515
#
# [89 rows x 2 columns]

# %%
plt.figure(figsize=(20,6)) 
plt.plot(df_daily_sale['month_year'],df_daily_sale['Total'], color='red')
plt.xticks(rotation = 'vertical', size=8)
plt.show()

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#       Invoice_ID Branch       City Customer_type  Gender  \
# 0    101-17-6199      A     Yangon        Normal    Male
# 1    101-81-4070      C  Naypyitaw        Member  Female
# 2    102-06-2002      C  Naypyitaw        Member    Male
# 3    102-77-2261      C  Naypyitaw        Member    Male
# 4    105-10-6182      A     Yangon        Member    Male
# 5    105-31-1824      A     Yangon        Member    Male
# 6    106-35-6779      A     Yangon        Member    Male
# 7    109-28-2512      B   Mandalay        Member  Female
# 8    109-86-4363      B   Mandalay        Member  Female
# 9    110-05-6330      C  Naypyitaw        Normal  Female
# 10   110-48-7033      B   Mandalay        Member    Male
# 11   114-35-5271      B   Mandalay        Normal  Female
# 12   115-38-7388      C  Naypyitaw        Member  Female
# 13   115-99-4379      B   Mandalay        Member  Female
# 14   118-62-1812      C  Naypyitaw        Member  Female
# ...

# %% [markdown]
# # <h2> which are the top products by sales?

# %%
# Grouping product name column

prod_lines = pd.DataFrame(df.groupby('Product_line').sum()['Total'])

# %%
#sorting prod_sales column
prod_lines =prod_lines.sort_values('Total',ascending=False)
prod_lines
# Out:
#                              Total
# Product_line
# Food and beverages      56144.8440
# Sports and travel       55122.8265
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Home and lifestyle      53861.9130
# Health and beauty       49193.7390

# %% [markdown]
# # which are the most selling product?

# %%
prod_quantity=pd.DataFrame(df.groupby('Product_line').sum()['Quantity'])

# %%
prod_quantity= prod_quantity.sort_values('Quantity',ascending=False)
prod_quantity
# Out:
#                         Quantity
# Product_line
# Electronic accessories       971
# Food and beverages           952
# Sports and travel            920
# Home and lifestyle           911
# Fashion accessories          902
# Health and beauty            854

# %% [markdown]
# # Type of payment

# %%
payment_mode= pd.DataFrame(df.groupby('Payment').count()['Invoice_ID'])
payment_mode
# Out:
#              Invoice_ID
# Payment
# Cash                344
# Credit card         311
# Ewallet             345

# %%
payment_mode= payment_mode.sort_values('Invoice_ID',ascending=False)
payment_mode
# Out:
#              Invoice_ID
# Payment
# Ewallet             345
# Cash                344
# Credit card         311

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['Payment'])
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # # More profitable city

# %%
profit_city=pd.DataFrame(df.groupby(['City']).sum()['gross_income'])

# %%
profit_city= profit_city.sort_values('gross_income',ascending=False)
profit_city
# Out:
#            gross_income
# City
# Naypyitaw     5265.1765
# Yangon        5057.1605
# Mandalay      5057.0320
